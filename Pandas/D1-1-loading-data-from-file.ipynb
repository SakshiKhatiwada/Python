# %%
import pandas as pd

coffee = pd.read_csv('complete-pandas-tutorial/warmup-data/coffee.csv')

# coffee.head()

# %%
results = pd.read_parquet("complete-pandas-tutorial/data/results.parquet")
bios = pd.read_csv("complete-pandas-tutorial/data/bios.csv")
# results.head()

# %%
# olympics_data = pd.read_excel(
#     "complete-pandas-tutorial/data/olympics-data.xlsx", sheet_name="results"
# )

# %%
# olympics_data.head()

# %% [markdown]
# To ...

# %%
# bios.to_excel()# to apply directly

# %% [markdown]
# # Accessing Data with Pandas 🐼

# %%
coffee
# NOTE The head() method returns the first 5 rows if a number is not specified
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# # To access Random Data

# %%
# coffee.sample(10)
coffee.sample(10, random_state=1)
# NOTE - determining random_state=1, the same rows will appear on every run as per the first time, else it would have just changed every single time!!!
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %% [markdown]
# # #SECTION - Day2 - To access items by mentioning

# %%
# SECTION - loc()

coffee.loc[0]
coffee.loc[[0, 2, 4]]  # gotta pass list
coffee.loc[0:3]  # slice syntaxs
# NOTE - can have rows and columns
# coffee.loc[5:8, ["Day", 'Units Sold']]
# coffee.loc[5:8, 2:3] # ERR - can't use numbers for columns, only labels
# NOTE - .loc selects data using row and column names (labels), while .iloc uses numerical indices (positions).
# coincidentally our row name was numbers, so couldn't separate earlier!!
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
# SECTION - iloc()

# coffee.iloc[:, [0,2]]
coffee.iloc[0:5, 0:3]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# coffee.index = coffee.Day
# coffee.index = coffee["Day"]
# coffee
# coffee.loc["Monday":"Tuesday"]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# # Updating Data Vaues

# %%
#SECTION updating data values

coffee.loc[1:3, "Units Sold"] = 100

coffee.at[0,"Units Sold"] = 37
coffee.iat[0,2] = 47
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          47
# 1      Monday       Latte         100
# 2     Tuesday    Espresso         100
# 3     Tuesday       Latte         100
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# SECTION - accessing data

# coffee.Day # for single word
# coffee["Day"] # for single value
coffee[["Day", "Coffee Type"]]  # for multiple values, lists
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
#SECTION - sorting

coffee.sort_values("Units Sold", ascending=False)
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=False) #multiple constraint
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte         100
# 3     Tuesday       Latte         100
# 2     Tuesday    Espresso         100
# 0      Monday    Espresso          47
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25

# %%
#SECTION iterating (not recommended as performance is lost)

for index,row in coffee.iterrows():
    print(index," ", row["Units Sold"])
# Out:
# 0   47
# 1   100
# 2   100
# 3   100
# 4   35
# 5   25
# 6   40
# 7   30
# 8   45
# 9   35
# 10   45
# 11   35
# 12   45
# 13   35
