# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True) # set True means we will perform derivatives. It records operations on the tensor
y = x**2

# %%
print(x,y)
# Out:
# tensor(3., requires_grad=True) tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward() # calculates the derivative

# %%
x.grad # shows the derivative
# Out:
# tensor(6.)
