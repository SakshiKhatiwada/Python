# %%
import pickle

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
import numpy as np
test_data = np.array([2, 'female', 31.0, 0, 0, 10.5, 'S'], dtype=object).reshape(1,7)
test_data
# Out:
# array([[2, 'female', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
pipe.predict(test_data)
# Out:
# /home/sakshi-khatiwada/Desktop/My Repos/Python/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/sakshi-khatiwada/Desktop/My Repos/Python/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
