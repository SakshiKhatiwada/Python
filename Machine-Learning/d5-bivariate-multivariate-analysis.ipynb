# %% [markdown]
# # Bivariate/Multivariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')
titanic = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# # 1. Scatterplot (Numerical - Numerical)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'], hue=df['sex'], style=df['size'], size = df['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Barplot (Numerical-Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x = titanic['Pclass'], y = titanic['Age'], hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 3. BoxPlot (N-C)

# %%
sns.boxplot(x=titanic['Sex'], y=titanic['Age'], hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4. Displot (N-C)

# %%
# sns.histplot(titanic[titanic['Survived'] == 0]['Age'], kde=True, element='poly')
# sns.histplot(titanic[titanic['Survived'] == 1]['Age'], kde=True, element=None) ['bar', 'step', 'poly']

# directly using kdeplot
sns.kdeplot(titanic[titanic['Survived'] == 0]['Age'], fill=False)
sns.kdeplot(titanic[titanic['Survived'] == 1]['Age'], fill=False)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>
