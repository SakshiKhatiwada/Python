# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gas = pd.read_csv("data/gas_prices_downloaded-KG.csv")

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.figure(figsize=(8, 5))

# plt.plot(gas.Year, gas.USA, 'c.-', label="USA", markerfacecolor='r', markersize=8)
# plt.plot(gas.Year, gas.Canada, 'r.-', label="Canada", markerfacecolor='c', markersize=8)
# plt.plot(gas.Year, gas["South Korea"], 'g.-', label="South Korea", markerfacecolor='r', markersize=8)
# plt.plot(gas.Year, gas["Australia"], 'y.-', label="South Korea", markerfacecolor='c', markersize=8)


# or do countries to look at
countries_to_look_at = ['USA', "Canada", "Australia"]
# for country in gas.columns[1:]:  # from columns 1 onwards
for country in countries_to_look_at:  # from columns 1 onwards
    # print(country)
    plt.plot(gas.Year, gas[country], ".-", label=country, markersize=8)


plt.title("Gas Prices in USA VS Canada", fontdict={"fontsize": 20, "fontname": "Comic Sans MS", "fontweight": "bold", "color": "blue"})
plt.xlabel("Year")
plt.ylabel("Gas prise in $ per gallon")

# plt.xticks(gas.Year)
# plt.xticks(gas.Year[::3]+2011, rotation=45) *ERR - it's a dataframe, we can't add 2011 directly
# plt.xticks(gas.Year[::3] + [2011], rotation=45) # tip make a list, *ERR - still did *NOT work
plt.xticks(gas.Year[::3].tolist() + [2011], rotation=45)

# plt.legend(loc="upper left")
plt.legend(bbox_to_anchor=(1, 1), loc="upper left", title="Countries")
# INFO bbox_to_anchor=(1.05, 1) moves the legend slightly outside the plot to the right.
#INFO bbox_to_anchor=(1.05, 1), loc='upper left' The legend's upper-left corner is placed at (1.05, 1), so it fully moves outside the plot

plt.savefig("Data/D1-2-graph.png", dpi = 300, bbox_inches='tight') # bbox_inches='tight' to avoid cutting off the legend
plt.show()
